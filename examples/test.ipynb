# %%
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
with open('cars.json') as f:
    data = json.load(f)

# %%
df = pd.DataFrame(data['data']).set_index("index")

# %%
df.median(numeric_only=True)
# Out:
# Horsepower           150.00
# Miles_per_Gallon      17.50
# Acceleration          11.25
# Weight_in_lbs       3442.50
# Cylinders              8.00
# Displacement         312.50
# dtype: float64

# %%
# plot the dataframe as a bar chart
df.plot.bar()
# Out:
# <Axes: xlabel='index'>

# %%
# remove column Horsepower
