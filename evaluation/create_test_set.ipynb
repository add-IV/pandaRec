# %%
import sys
import json
import pandas as pd
sys.path.append('../')
from pandaRec import Recipe, Recommender
from pandaRec.strategies import NameSearch, FuzzySearchName, FuzzySearchDescription, IndexSearch, SemanticSearch

# %%
df = pd.read_csv('test_data.csv', sep=';', names=["name", "query"])

# %%
with open('../recipes/recipes.json') as f:
    recipes = json.load(f)

recipes = [Recipe.from_dict(r) for r in recipes]

# %%
len(recipes)
# Out:
# 185

# %%
recommenders = [None]*5

# %%
recommenders[0] = Recommender(recipes, df, NameSearch())
recommenders[1] = Recommender(recipes, df, FuzzySearchName())
recommenders[2] = Recommender(recipes, df, FuzzySearchDescription())
recommenders[3] = Recommender(recipes, df, IndexSearch(recipes))
recommenders[4] = Recommender(recipes, df, SemanticSearch(recipes, '../recipes/embeddings.pt'))
# Out:
# 185

# %%
from pandaRec.search_index import save_search_index

# %%
len(recipes)
# Out:
# 185

# %%
def get_recommender_result(recommender, query):
    recommender.set_search(query)
    recommender.recommend()
    results = recommender.show_results(5)
    results = [r.recipe.name for r in results]
    return results

for recommender in recommenders:
    print(recommender.strategy.__class__.__name__)
    df[recommender.strategy.__class__.__name__] = df['query'].apply(lambda x: get_recommender_result(recommender, x))
# Out:
# NameSearch
# FuzzySearchName
# FuzzySearchDescription
# IndexSearch
# SemanticSearch

# %%
df
# Out:
#                   name                                              query  \
# 0            read file                  read a file to a pandas dataframe
# 1                 head                              show the first 5 rows
# 2                 tail                               show the last 5 rows
# 3              columns                              show the column names
# 4                 drop                           drop unnecessary columns
# 5                  len                    get the length of the dataframe
# 6                query                    show rows that meet a condition
# 7                 iloc                      get a subset of the dataframe
# 8               dtypes                      show the types of the columns
# 9        select dtypes                       only show certain data types
# 10              insert          insert a column in the specified position
# 11      cumulative sum                       calculate the cumulative sum
# 12              sample             get a random sample of rows or columns
# 13               where               query a dataset based on a condition
# 14              unique                      get unique values of a column
# 15             nunique        get the number of unique values of a column
# 16                rank         get the rank of the rows based on a clomun
# 17                isin           get rows that contain values from a list
# 18             replace            replace one value by another everywhere
# 19              rename                                    rename a column
# 20              fillna                                fill up null values
# 21             groupby                                         group data
# 22   percentage change  get the percentage change from the previous value
# 23               count          count how many entries are in each column
# 24        value counts       how often does each value occur for a column
# 25           crosstabs  give the frequency of how often one value in o...
# 26                 cut                           bin the data into 5 bins
# 27            describe                     give basic info about a column
# 28  nlargest nsmallest                           get the 5 largest values
# 29             explode          change a list of data into unique entries
#
#    NameSearch                                    FuzzySearchName  \
# 0          []  [to_clipboard, to_csv, to_dict, to_excel, to_f...
# 1          []        [first, combine_first, hist, rpow, to_list]
# 2          []                    [last, rpow, to_list, abs, pow]
# 3          []                   [cov, rename, cummin, keys, min]
# 4          []        [drop, drop_duplicates, dropna, cummin, ne]
# 5          []             [rename, to_frame, head, asfreq, mean]
# 6          []                [rpow, at_time, last, count, round]
# 7          []             [rename, to_frame, head, rsub, asfreq]
# 8          []  [asof, astype, cummin, value_counts, convert_d...
# 9          []        [astype, tail, keys, convert_dtypes, align]
# 10         []  [cummin, sort_values, set_axis, to_string, kur...
# 11         []              [last, rmul, at_time, cummax, cumsum]
# 12         []                [sample, resample, cummin, ge, get]
# 13         []      [set_axis, dropna, set_flags, unique, update]
# 14         []       [unique, sort_values, nunique, asof, cummin]
# 15         []         [unique, sort_values, nunique, cummin, ge]
# 16         []                   [dropna, ge, get, rank, combine]
# 17         []      [sort_values, to_list, ge, get, value_counts]
# 18         []  [replace, where, value_counts, repeat, sort_va...
# 19         []         [rename, min, mean, rename_axis, resample]
# 20         []           [sort_values, bfill, ffill, fillna, all]
# 21         []                        [update, drop, dot, ge, gt]
# 22         []   [pct_change, value_counts, sort_values, ge, get]
# 23         []            [reindex, unstack, argmin, cummin, any]
# 24         []  [value_counts, sort_values, cummin, combine, c...
# 25         []  [to_clipboard, to_timestamp, value_counts, cor...
# 26         []                 [head, info, tail, align, combine]
# 27         []               [info, cummin, mean, combine, count]
# 28         []  [sort_values, nlargest, argsort, keys, value_c...
# 29         []  [unique, pct_change, to_list, nunique, iteritems]
#
#                                FuzzySearchDescription  \
# 0            [backfill, shift, tz_localize, abs, agg]
# 1                  [compare, first, head, hist, info]
# 2                [hist, isna, isnull, notna, notnull]
# 3   [add_prefix, add_suffix, append, astype, at_time]
# 4   [asof, astype, autocorr, compare, convert_dtypes]
# 5      [add_prefix, add_suffix, asfreq, asof, astype]
# 6                    [loc, isin, add, astype, filter]
# 7             [pct_change, align, any, append, apply]
# 8                 [append, to_csv, to_list, abs, agg]
# 9                       [append, dot, info, abs, add]
# 10         [mad, any, sort_index, between_time, drop]
# 11             [cummax, cummin, cumprod, cumsum, ewm]
# 12                  [drop, ewm, take, cummax, cummin]
# 13          [to_csv, cummax, cummin, cumprod, cumsum]
# 14      [nunique, diff, unique, abs, drop_duplicates]
# 15         [nunique, cummax, cummin, cumprod, cumsum]
# 16  [between, pct_change, append, combine, combine...
# 17       [to_list, swapaxes, combine, cov, factorize]
# 18                  [loc, all, compare, mode, dropna]
# 19  [rename_axis, add_prefix, add_suffix, all, at_...
# 20      [head, info, reindex_like, reset_index, tail]
# 21               [groupby, hist, kurt, kurtosis, loc]
# 22    [pct_change, count, swapaxes, argsort, between]
# 23            [count, xs, align, convert_dtypes, dot]
# 24                [iloc, mean, median, skew, to_list]
# 25  [infer_objects, to_sql, diff, duplicated, filter]
# 26                   [pipe, any, astype, count, drop]
# 27              [items, equals, ewm, iteritems, rank]
# 28        [count, nlargest, nsmallest, pop, resample]
# 29       [drop_duplicates, info, item, to_latex, var]
#
#                                           IndexSearch  \
# 0        [to_latex, describe, info, to_csv, to_excel]
# 1            [groupby, argmax, argmin, asof, compare]
# 2               [asof, compare, first, groupby, head]
# 3           [compare, groupby, info, plot, to_string]
# 4   [drop, resample, reset_index, add_prefix, add_...
# 5            [all, between_time, corr, cov, describe]
# 6                 [plot, compare, groupby, info, loc]
# 7        [all, asof, between_time, describe, explode]
# 8             [groupby, rank, align, astype, compare]
# 9                 [groupby, rank, truncate, abs, add]
# 10                   [ewm, loc, plot, take, to_latex]
# 11       [cummax, cummin, cumprod, cumsum, expanding]
# 12                    [info, sample, to_sql, std, xs]
# 13              [describe, first, last, loc, replace]
# 14      [between_time, describe, get, info, to_excel]
# 15          [describe, info, to_excel, to_sql, align]
# 16                [info, xs, between_time, drop, ewm]
# 17          [groupby, to_csv, to_excel, asof, cummax]
# 18    [compare, plot, replace, resample, reset_index]
# 19  [rename_axis, add_prefix, add_suffix, align, all]
# 20                  [asfreq, fillna, align, all, any]
# 21            [asfreq, groupby, plot, rank, resample]
# 22  [diff, pct_change, astype, between_time, combine]
# 23                     [info, align, all, any, count]
# 24                    [align, all, any, asof, astype]
# 25        [compare, plot, resample, reset_index, all]
# 26        [asfreq, resample, value_counts, hist, abs]
# 27  [convert_dtypes, filter, info, reindex, add_pr...
# 28        [argmax, between_time, get, idxmax, idxmin]
# 29     [to_excel, describe, drop, factorize, reindex]
#
#                                        SemanticSearch
# 0   [to_hdf, to_markdown, to_csv, to_clipboard, to...
# 1            [head, tail, to_string, first, truncate]
# 2             [tail, head, last, to_string, truncate]
# 3   [to_latex, to_string, add_prefix, add_suffix, ...
# 4    [droplevel, dropna, drop, reset_index, truncate]
# 5                  [tail, head, info, count, nunique]
# 6                      [filter, head, isin, all, any]
# 7                   [filter, head, xs, truncate, loc]
# 8   [to_latex, convert_dtypes, plot, to_string, info]
# 9   [convert_dtypes, to_string, infer_objects, to_...
# 10  [searchsorted, add_prefix, to_excel, add_suffi...
# 11             [cumsum, cumprod, sum, cummax, cummin]
# 12         [sample, describe, std, var, value_counts]
# 13         [filter, isin, between_time, between, get]
# 14  [unique, nunique, drop_duplicates, factorize, ...
# 15  [nunique, value_counts, count, duplicated, fac...
# 16               [rank, idxmax, tail, argmax, idxmin]
# 17  [isin, first_valid_index, filter, last_valid_i...
# 18  [replace, swapaxes, update, reindex_like, back...
# 19  [add_prefix, add_suffix, rename, rename_axis, ...
# 20    [combine_first, dropna, fillna, notnull, notna]
# 21            [groupby, combine, rank, var, nlargest]
# 22             [pct_change, diff, quantile, abs, mad]
# 23          [nunique, count, value_counts, tail, all]
# 24  [value_counts, nunique, describe, std, duplica...
# 25   [value_counts, corr, duplicated, isin, autocorr]
# 26   [hist, describe, value_counts, median, resample]
# 27             [to_latex, info, head, describe, tail]
# 28         [argmax, nlargest, idxmax, max, nsmallest]
# 29  [drop_duplicates, explode, unique, duplicated,...
